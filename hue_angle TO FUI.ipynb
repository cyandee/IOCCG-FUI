# %%
import pandas as pd 
fui = pd.read_excel('/Users/cyano/Desktop/FUI/IOCCG-TSI.xlsx')
hue_angle = fui['hue_angle']

# %%
type(hue_angle)
# Out:
# pandas.core.series.Series

# %%
fui = []
fui_level = list(range(1,22))
angle_tran = [360, 220.977, 209.994, 190.779, 163.084, 132.999,
            109.054, 94.037, 83.346, 74.572, 67.957, 62.186, 56.435,
            50.665, 45.129, 39.769, 34.906, 30.439, 26.337, 22.741, 0]
for t in hue_angle:
    i = 0
    while t < angle_tran[i]:                         
        i += 1
    fui.append(i+1)

# %%
type(fui)
# Out:
# list

# %%
fui
# Out:
# [3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  3,
#  2,
#  2,
#  3,
#  3,
#  2,
#  3,
#  2,
#  3,
#  2,
#  3,
#  2,
#  3,
#  2,
#  2,
#  2,
#  3,
#  3,
#  3,
#  2,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  3,
#  2,
#  2,
#  3,
#  2,
#  3,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
# ...
